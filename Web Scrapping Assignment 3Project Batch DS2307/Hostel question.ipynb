# %%
# !pip install selenium

# %%
import selenium
from selenium import webdriver
import pandas as pd
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import warnings
warnings.filterwarnings("ignore")
import time

# %%
driver=webdriver.Chrome(r'C:\Users\maham\Downloads\chromedriver-win64\chromedriver-win64\chromedriver.exe')#WORKING WITH NEW CHROME 116 UPDATE
driver.maximize_window()

# %%
#9 Write a python program to scrape a data for all available Hostels from https://www.hostelworld.com/ in “London” location
url = "https://www.hostelworld.com/s?q=London,%20England&country=England&city=London&type=city&id=3&from=2023-10-03&to=2023-10-04&guests=1&page=1"

# Send an HTTP GET request to the URL
response = driver.get(url)

# %%
Hostels=[]
title_tags=driver.find_elements(By.XPATH,"//div[@class='property-name']")
for i in title_tags:
    Hostels.append(i.text)
    
    
Hostels
# Out:
# ["St Christopher's Village",
#  'Palmers Lodge - Swiss Cottage',
#  "Wombat's City Hostel London",
#  "St Christopher's Village",
#  'Onefam Notting Hill',
#  'NX London Hostel',
#  'Urbany Hostel London',
#  'Generator London',
#  'Astor Hyde Park',
#  'Safestay London Elephant & Castle',
#  'Phoenix Hostel',
#  'Clink261',
#  'Astor Museum Inn',
#  'Smart Russell Square Hostel',
#  'Smart Hyde Park Inn Hostel',
#  'Safestay London Kensington Holland Park',
#  'The Walrus Hostel',
#  'Destinations Hostels @ The Gallery',
#  'Astor Victoria',
#  'Barmy Badger Backpackers',
#  'London Backpackers',
#  "St Christopher's Inn - London Bridge",
#  "St Christopher's Hammersmith",
#  'Hostelle - women only hostel London',
#  'YHA London Oxford Street',
#  "St Christopher's Camden",
#  'Kabannas London St Pancras',
#  'Prime Backpackers Angel',
#  'Bell House Hostel',
#  'Astor Kensington',
#  'Saint James Backpackers',
#  "St Christopher's Greenwich"]

# %%
distance_from_center=[]
title_tags=driver.find_elements(By.XPATH,"//span[@class='distance-description']")
for i in title_tags:
    distance_from_center.append(i.text[2:7])
    
distance_from_center.insert(0,"-")    
distance_from_center.insert(1,"-")    
    
distance_from_center
# Out:
# ['-',
#  '-',
#  '3.6km',
#  '1.8km',
#  '5.5km',
#  '6.1km',
#  '5.4km',
#  '3km f',
#  '4.3km',
#  '1.7km',
#  '4.2km',
#  '3.2km',
#  '2.2km',
#  '2.6km',
#  '5km f',
#  '5.8km',
#  '0.2km',
#  '1.7km',
#  '1.8km',
#  '5.5km',
#  '11.9k',
#  '1.8km',
#  '7.5km',
#  '5.1km',
#  '2.1km',
#  '4.3km',
#  '3.3km',
#  '3.6km',
#  '4.2km',
#  '4.9km',
#  '5.5km',
#  '7.6km']

# %%
ratings=[]
title_tags=driver.find_elements(By.XPATH,"//span[@class='number']")
for i in title_tags:
    ratings.append(i.text)
    
    
ratings
# Out:
# ['8.2',
#  '8.6',
#  '9.0',
#  '8.2',
#  '9.7',
#  '8.3',
#  '9.5',
#  '7.6',
#  '8.3',
#  '7.2',
#  '7.5',
#  '8.1',
#  '8.1',
#  '7.4',
#  '7.5',
#  '7.0',
#  '8.2',
#  '9.2',
#  '7.0',
#  '9.0',
#  '7.8',
#  '7.9',
#  '7.4',
#  '8.7',
#  '8.8',
#  '7.4',
#  '8.6',
#  '7.8',
#  '7.7',
#  '8.0',
#  '7.7',
#  '7.7']

# %%
total_reviews=[]
title_tags=driver.find_elements(By.XPATH,"//span[@class='left-margin']")
for i in title_tags:
    total_reviews.append(i.text)
    
    

total_reviews.insert(0,"-")
total_reviews.insert(1,"-")
len(total_reviews)
total_reviews
# Out:
# ['-',
#  '-',
#  '(15265)',
#  '(12379)',
#  '(2233)',
#  '(2093)',
#  '(895)',
#  '(7714)',
#  '(12162)',
#  '(5093)',
#  '(4386)',
#  '(385)',
#  '(9326)',
#  '(10081)',
#  '(6703)',
#  '(1637)',
#  '(4191)',
#  '(221)',
#  '(15015)',
#  '(1971)',
#  '(4510)',
#  '(3539)',
#  '(4295)',
#  '(28)',
#  '(4652)',
#  '(4087)',
#  '(2887)',
#  '(789)',
#  '(92)',
#  '(6531)',
#  '(1918)',
#  '(3381)']

# %%
overall_reviews=[]
title_tags=driver.find_elements(By.XPATH,"//span[@class='keyword']")
for i in title_tags:
    overall_reviews.append(i.text)
    
    


len(overall_reviews)
overall_reviews
# Out:
# ['Fabulous',
#  'Fabulous',
#  'Superb',
#  'Fabulous',
#  'Superb',
#  'Fabulous',
#  'Superb',
#  'Very Good',
#  'Fabulous',
#  'Very Good',
#  'Very Good',
#  'Fabulous',
#  'Fabulous',
#  'Very Good',
#  'Very Good',
#  'Very Good',
#  'Fabulous',
#  'Superb',
#  'Very Good',
#  'Superb',
#  'Very Good',
#  'Very Good',
#  'Very Good',
#  'Fabulous',
#  'Fabulous',
#  'Very Good',
#  'Fabulous',
#  'Very Good',
#  'Very Good',
#  'Fabulous',
#  'Very Good',
#  'Very Good']

# %%
property_desc=[]
title_tags=driver.find_elements(By.XPATH,"//a[@class='property-card-container horizontal']")
for i in title_tags:
    l=i.get_attribute("href")
    property_desc.append(l)
    
property_desc.insert(0,"-")
property_desc.insert(1,"-")
property_desc.insert(1,"-")
len(property_desc)
# Out:
# 32

# %%
price=[]
money=[]
dorm=[]
private=[]
title_tags=driver.find_elements(By.XPATH,"//div[@class='accommodation-price']")
for i in title_tags:
    money.append(i.text)
    
for i in range(0,end):
    k=money[i].split("\n")
    price.append(k)

    
price.insert(1,"-")
price.insert(3,"-")

title_tags=driver.find_elements(By.XPATH,"//strong[@class='current']")
for i in title_tags:
    price.append(i.text)
    

    
price.insert(16,"-")
price.insert(24,"-")
price.insert(26,"-")
price.insert(28,"-")
price.insert(32,"-")
price.insert(36,"-")
price.insert(41,"-")
price.insert(42,"-")
price.insert(46,"-")
price.insert(49,"-")
price.insert(50,"-")
price.insert(52,"-")
price.insert(62,"-")


len(price)
# Out:
# 64

# %%
for j in range(0,len(price)):
        if (j % 2 == 0):
            private.append(price[j])
        else:
            dorm.append(price[j])
            


print("Dorm prices ",dorm)
print("private prices",private)
# Out:
# Dorm prices  ['-', '-', '₹3,853', '₹2,488', '₹4,423', '₹1,603', '₹3,263', '₹2,532', '₹3,542', '₹3,186', '₹2,019', '₹3,542', '₹3,542', '₹2,100', '₹1,890', '₹2,329', '₹2,553', '₹4,949', '₹3,542', '₹2,813', '-', '₹3,216', '₹1,863', '₹3,334', '-', '₹2,592', '₹4,311', '₹2,750', '₹2,626', '₹3,542', '₹4,063', '₹1,863']
# private prices [['₹2,488'], ['₹2,629'], '₹12,806', '₹12,282', '₹21,592', '₹6,436', '₹16,860', '₹10,690', '-', '₹10,523', '₹8,462', '₹18,208', '-', '-', '-', '₹10,432', '-', '₹14,587', '-', '₹8,387', '₹5,908', '-', '₹21,647', '-', '₹11,461', '-', '-', '₹7,727', '₹7,689', '₹12,503', '₹12,151', '-']

# %%
print(len(Hostels),len(distance_from_center),len(ratings),len(total_reviews),len(overall_reviews),len(property_desc),len(dorm),len(private))
# Out:
# 32 32 32 32 32 32 32 32

# %%
import pandas as pd
df=pd.DataFrame({'Hostels':Hostels,'Distance from center':distance_from_center,'ratings':ratings,'total_reviews':total_reviews,'overall_reviews':overall_reviews,'property_desc':property_desc,'dorm':dorm,'Private':private})
df
# Out:
#                                     Hostels Distance from center ratings  \
# 0                  St Christopher's Village                    -     8.2
# 1             Palmers Lodge - Swiss Cottage                    -     8.6
# 2               Wombat's City Hostel London                3.6km     9.0
# 3                  St Christopher's Village                1.8km     8.2
# 4                       Onefam Notting Hill                5.5km     9.7
# 5                          NX London Hostel                6.1km     8.3
# 6                      Urbany Hostel London                5.4km     9.5
# 7                          Generator London                3km f     7.6
# 8                           Astor Hyde Park                4.3km     8.3
# 9         Safestay London Elephant & Castle                1.7km     7.2
# 10                           Phoenix Hostel                4.2km     7.5
# 11                                 Clink261                3.2km     8.1
# ...

# %%
df.to_csv(r'C:\Users\maham\OneDrive\Desktop\hostels.csv')

# %%
# Write a python program to scrape the details for all billionaires from www.forbes.com. Details to be scrapped: 
#“Rank”, “Name”, “Net worth”, “Age”, “Citizenship”, “Source”, “Industry”.
