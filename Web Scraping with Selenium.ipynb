# %%
# !pip install selenium

# %%
#Q1: Write a python program to scrape data for “Data Analyst” Job position in “Bangalore” location. You have to scrape the job-title, job-location, company_name, experience_required. You have to scrape first 10 jobs data

# %%
import selenium
from selenium import webdriver
import pandas as pd
from selenium.webdriver.common.by import By
import warnings
warnings.filterwarnings("ignore")
import time

# %%
driver=webdriver.Chrome(r'C:\Users\maham\Downloads\chromedriver\chromedriver.exe') #copy the path of the chromedriver

# %%
driver.maximize_window() #maximizing window

# %%
url='https://www.naukri.com/'
driver.get(url)

# %%
search_job=driver.find_element(By.CLASS_NAME,"suggestor-input ")
search_job.send_keys("Data Analyst")

# %%
search_loc=driver.find_element(By.XPATH,'/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input')
search_loc.send_keys("Banglore")

# %%
search_btn=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search_btn.click()

# %%
#extracting all web elemenys having job title
job_title=[]
title_tags=driver.find_elements(By.XPATH,"//a[@class='title fw500 ellipsis']")
for i in title_tags[0:10]:
    job_title.append(i.text)
    
job_title
# Out:
# ['Senior Data Analyst - PLM Data Migration',
#  'Associate Healthcare Research & Data Analyst',
#  'Lead Data Analyst',
#  'Contractual Hiring For Top MNC || Business Data Analyst || Bangalore',
#  'Master Data Management Business Analyst',
#  'Data Analyst',
#  'Sr. Data Analyst (SAS Data Management)',
#  'Data Analyst',
#  'Data Analyst',
#  'Lead Data Management Analyst']

# %%
len(job_title)
# Out:
# 10

# %%
#Job location 
job_location=[]
title_tags=driver.find_elements(By.XPATH,"//span[@class='ellipsis fleft fs12 lh16 locWdth']")
for i in title_tags[0:10]:
    job_location.append(i.text)
    
job_location
# Out:
# ['Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'New Delhi, Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Chennai, Bangalore/Bengaluru']

# %%
len(job_location)
# Out:
# 10

# %%
company_name=[]
title_tags=driver.find_elements(By.XPATH,"//a[@class='subTitle ellipsis fleft']")
for i in title_tags[0:10]:
    company_name.append(i.text)
    
company_name
# Out:
# ['CGI',
#  'Clarivate',
#  'Mobile Premier League (MPL)',
#  'TeamLease',
#  'Accenture',
#  'Elasticsearch',
#  'NMS Consultant',
#  'IBM',
#  'IBM',
#  'Wells Fargo']

# %%
exp=[]
title_tags=driver.find_elements(By.XPATH,"//span[@class='ellipsis fleft fs12 lh16 expwdth']")
for i in title_tags[0:10]:
    exp.append(i.text)
    
exp
# Out:
# ['3-6 Yrs',
#  '3-4 Yrs',
#  '4-7 Yrs',
#  '5-8 Yrs',
#  '6-8 Yrs',
#  '2-5 Yrs',
#  '5-10 Yrs',
#  '3-4 Yrs',
#  '3-4 Yrs',
#  '5-8 Yrs']

# %%
df=pd.DataFrame({'Company name':company_name,'Job title':job_title,'Job Location':job_location,'Experience':exp})
df
# Out:
#                   Company name  \
# 0                          CGI
# 1                    Clarivate
# 2  Mobile Premier League (MPL)
# 3                    TeamLease
# 4                    Accenture
# 5                Elasticsearch
# 6               NMS Consultant
# 7                          IBM
# 8                          IBM
# 9                  Wells Fargo
#
#                                            Job title  \
# 0           Senior Data Analyst - PLM Data Migration
# 1       Associate Healthcare Research & Data Analyst
# 2                                  Lead Data Analyst
# 3  Contractual Hiring For Top MNC || Business Dat...
# 4            Master Data Management Business Analyst
# 5                                       Data Analyst
# 6             Sr. Data Analyst (SAS Data Management)
# 7                                       Data Analyst
# 8                                       Data Analyst
# 9                       Lead Data Management Analyst
#
# ...

# %%
#In this question you have to scrape data using the filters available on the webpage as shown below:
#You have to use the location and salary filter.
#You have to scrape data for “Data Scientist” designation for first 10 job results.
#You have to scrape the job-title, job-location, company name, experience required.
#The location filter to be used is “Delhi/NCR”. The salary filter to be used is “3-6” lakhs

# %%
driver=webdriver.Chrome(r'C:\Users\maham\Downloads\chromedriver\chromedriver.exe') #copy the path of the chromedriver

# %%
url='https://www.naukri.com/'
driver.get(url)

# %%
search_job=driver.find_element(By.CLASS_NAME,"suggestor-input ")
search_job.send_keys("Data Scientist")

# %%
search_btn=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search_btn.click()

# %%
search_loc=driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/div/section[1]/div[2]/div[5]/div[2]/div[2]/label/p/span[1]').click()

# %%
search_salary=driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/div/section[1]/div[2]/div[6]/div[2]/div[2]/label/p/span[1]').click()

# %%
job_title=[]
title_tags=driver.find_elements(By.XPATH,"//a[@class='title fw500 ellipsis']")
for i in title_tags[0:10]:
    job_title.append(i.text)
    
job_title
# Out:
# ['Data Scientist',
#  'DigitalBCG GAMMA Data Scientist',
#  'Urgent hiring For Data Scientist (PHD Must Have)',
#  'Manager - Data Science - Banking&Financial Services - IIM/ISB/MDI/FMS',
#  'Data Scientist / Sr. Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data scientist- Python',
#  'Data Scientist']

# %%
#Job location 
job_location=[]
title_tags=driver.find_elements(By.XPATH,"//span[@class='ellipsis fleft fs12 lh16 locWdth']")
for i in title_tags[0:10]:
    job_location.append(i.text)
    
job_location
# Out:
# ['Noida, Hyderabad/Secunderabad, Chennai, Bangalore/Bengaluru',
#  'New Delhi, Bangalore/Bengaluru',
#  'Temp. WFH - Noida, Pune',
#  'Delhi / NCR, Bangalore/Bengaluru',
#  'Temp. WFH - Noida',
#  'Dehradun, Hyderabad/Secunderabad, Gurgaon/Gurugram',
#  'Noida',
#  'Noida',
#  'Gurgaon/Gurugram',
#  'New Delhi']

# %%
company_name=[]
title_tags=driver.find_elements(By.XPATH,"//a[@class='subTitle ellipsis fleft']")
for i in title_tags[0:10]:
    company_name.append(i.text)
    
company_name
# Out:
# ['HCLTech',
#  'Boston Consulting Group',
#  'NGI Ventures',
#  'Black Turtle',
#  'Wegarner Solutions',
#  'torcai digital media',
#  'Meon Technologies',
#  'Alliance Recruitment Agency',
#  'TeamPlus Staffing Solution Pvt Ltd',
#  'Razor Group GmbH']

# %%
df=pd.DataFrame({'Company name':company_name,'Job title':job_title,'Job Location':job_location})
df
# Out:
#                          Company name  \
# 0                             HCLTech
# 1             Boston Consulting Group
# 2                        NGI Ventures
# 3                        Black Turtle
# 4                  Wegarner Solutions
# 5                torcai digital media
# 6                   Meon Technologies
# 7         Alliance Recruitment Agency
# 8  TeamPlus Staffing Solution Pvt Ltd
# 9                    Razor Group GmbH
#
#                                            Job title  \
# 0                                     Data Scientist
# 1                    DigitalBCG GAMMA Data Scientist
# 2   Urgent hiring For Data Scientist (PHD Must Have)
# 3  Manager - Data Science - Banking&Financial Ser...
# 4                Data Scientist / Sr. Data Scientist
# 5                                     Data Scientist
# 6                                     Data Scientist
# 7                                     Data Scientist
# 8                             Data scientist- Python
# ...

# %%
#Scrape data of first 100 sunglasses listings on flipkart.com. You have to scrape four attributes:
#1. Brand
#2. Product Description
#3. Price

# %%
driver=webdriver.Chrome(r'C:\Users\maham\Downloads\chromedriver\chromedriver.exe') #copy the path of the chromedriver

# %%
url='https://www.flipkart.com/'
driver.get(url)

# %%
search_product=driver.find_element(By.CLASS_NAME,"_3704LK")
search_product.send_keys("Sunglasses")

# %%
click_search=driver.find_element(By.CLASS_NAME,"L0Z3Pu").click()

# %%
Brand=[]
start=0
end=2
for page in range(start,end):
    titles=driver.find_elements(By.XPATH,"//div[@class='_2WkVRV']")
    for i in titles:
        Brand.append(i.text)
    next_button=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[3]')
    next_button.click()
    time.sleep(3)
    
for j in titles[0:20]:
    Brand.append(j.text)
next_button=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[4]')
next_button.click()
time.sleep(3)
    
Brand
# Out:
# ['ROZZETTA CRAFT',
#  'CRYSTAL CART',
#  'ROZZETTA CRAFT',
#  'NuVew',
#  'kingsunglasses',
#  'IDEE',
#  'ROZZETTA CRAFT',
#  'Poshh eyewear',
#  'ROYAL SON',
#  'IDEE',
#  'ROZZETTA CRAFT',
#  'DEXENT COLLECTION',
#  'Fastrack',
#  'Fastrack',
#  'kingsunglasses',
#  'SUNBEE',
#  'ROZZETTA CRAFT',
#  'OCHILA',
#  'PHENOMENAL',
#  'SHAAH COLLECTIONS',
#  'Singco India',
#  'Fair-x',
#  'Urbanic',
#  'PIRASO',
#  'Fastrack',
#  'ROYAL SON',
#  'ROYAL SON',
#  'PROVOGUE',
#  'ROZZETTA CRAFT',
#  'ROYAL SON',
#  'ROZZETTA CRAFT',
#  'ROYAL SON',
#  'SHAAH COLLECTIONS',
#  'VINCENT CHASE',
#  'Ray-Ban',
#  'VINCENT CHASE',
#  'Singco India',
#  'ROZZETTA CRAFT',
#  'VINCENT CHASE',
#  'IDEE',
#  'ROZZETTA CRAFT',
#  'ROYAL SON',
#  'PIRASO',
#  'Fastrack',
#  'Fastrack',
#  'kingsunglasses',
#  'ROYAL SON',
#  'ROYAL SON',
#  'MODE',
#  'Urbanic',
#  'ROYAL SON',
#  'Sewell',
#  'Fastrack',
#  'Anemone',
#  'Urbanic',
#  'AISLIN',
#  'ROYAL SON',
#  'ROYAL SON',
#  'Lee Topper',
# ...

# %%
len(Brand)
# Out:
# 100

# %%
Product_description=[]
start=0
end=2
for page in range(start,end):
    titles=driver.find_elements(By.XPATH,"//a[@class='IRpwTa']")
    for i in titles:
        Product_description.append(i.text)
    next_button=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[3]')
    next_button.click()
    time.sleep(3)
    
for j in titles[0:21-1]:
    Product_description.append(j.text)
next_button=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[4]')
next_button.click()
time.sleep(3)
    
Product_description
# Out:
# ['UV Protection Over-sized Sunglasses (61)',
#  'UV Protection, Gradient Butterfly Sunglasses (52)',
#  'UV Protection Retro Square Sunglasses (Free Size)',
#  'UV Protection Sports Sunglasses (62)',
#  'UV Protection Aviator Sunglasses (18)',
#  'UV Protection Round Sunglasses (52)',
#  'Polarized, UV Protection Aviator Sunglasses (57)',
#  'Polarized, UV Protection Retro Square Sunglasses (61)',
#  'UV Protection Wayfarer Sunglasses (52)',
#  'Mirrored, UV Protection Wayfarer Sunglasses (Free Size)',
#  'UV Protection, Gradient Sunglass',
#  'UV Protection Retro Square Sunglasses (60)',
#  'UV Protection, Polarized, Mirrored Round Sunglasses (Fr...',
#  'Mirrored Aviator Sunglasses (55)',
#  'Gradient, UV Protection Aviator Sunglasses (58)',
#  'UV Protection, Night Vision Wayfarer Sunglasses (Free S...',
#  'Polarized, UV Protection Aviator Sunglasses (64)',
#  'Polarized, UV Protection Sports Sunglasses (68)',
#  'UV Protection, Mirrored Retro Square Sunglasses (53)',
# ...

# %%
len(Product_description)
# Out:
# 100

# %%
Price=[]
start=0
end=2
for page in range(start,end):
    titles=driver.find_elements(By.XPATH,"//div[@class='_30jeq3']")
    for i in titles:
        Price.append(i.text)
    next_button=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[3]')
    next_button.click()
    time.sleep(3)
    
for j in titles[0:20]:
    Price.append(j.text)
next_button=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[4]')
next_button.click()
time.sleep(3)
    
Price
# Out:
# ['₹759',
#  '₹854',
#  '₹474',
#  '₹345',
#  '₹909',
#  '₹539',
#  '₹699',
#  '₹664',
#  '₹579',
#  '₹260',
#  '₹664',
#  '₹664',
#  '₹324',
#  '₹379',
#  '₹1,169',
#  '₹282',
#  '₹759',
#  '₹254',
#  '₹399',
#  '₹179',
#  '₹1,234',
#  '₹664',
#  '₹251',
#  '₹699',
#  '₹539',
#  '₹474',
#  '₹664',
#  '₹1,234',
#  '₹178',
#  '₹664',
#  '₹471',
#  '₹1,399',
#  '₹5,339',
#  '₹629',
#  '₹949',
#  '₹474',
#  '₹699',
#  '₹759',
#  '₹999',
#  '₹949',
#  '₹474',
#  '₹209',
#  '₹251',
#  '₹649',
#  '₹222',
#  '₹809',
#  '₹426',
#  '₹426',
#  '₹219',
#  '₹178',
#  '₹379',
#  '₹575',
#  '₹498',
#  '₹359',
#  '₹719',
#  '₹439',
#  '₹249',
#  '₹269',
#  '₹579',
#  '₹379',
#  '₹759',
#  '₹227',
#  '₹179',
#  '₹299',
#  '₹449',
#  '₹236',
#  '₹616',
#  '₹296',
#  '₹469',
#  '₹1,009',
#  '₹664',
#  '₹331',
#  '₹649',
#  '₹189',
#  '₹199',
#  '₹230',
#  '₹664',
#  '₹299',
#  '₹664',
#  '₹474',
#  '₹474',
#  '₹209',
#  '₹251',
#  '₹649',
#  '₹222',
#  '₹809',
#  '₹426',
#  '₹426',
#  '₹219',
# ...

# %%
len(Price)
# Out:
# 100

# %%
Sun_glasses=pd.DataFrame()
Sun_glasses['Brand']=Brand
Sun_glasses['Product_description']=Product_description
Sun_glasses['Price']=Price
Sun_glasses
# Out:
#              Brand                                Product_description Price
# 0   ROZZETTA CRAFT           UV Protection Over-sized Sunglasses (61)  ₹759
# 1     CRYSTAL CART  UV Protection, Gradient Butterfly Sunglasses (52)  ₹854
# 2   ROZZETTA CRAFT  UV Protection Retro Square Sunglasses (Free Size)  ₹474
# 3            NuVew               UV Protection Sports Sunglasses (62)  ₹345
# 4   kingsunglasses              UV Protection Aviator Sunglasses (18)  ₹909
# ..             ...                                                ...   ...
# 95          AISLIN         Others Retro Square Sunglasses (Free Size)  ₹439
# 96       ROYAL SON   Polarized, UV Protection Aviator Sunglasses (55)  ₹249
# 97       ROYAL SON              UV Protection Aviator Sunglasses (58)  ₹269
# 98      Lee Topper              UV Protection Aviator Sunglasses (57)  ₹579
# 99            hipe  UV Protection, Gradient Rectangular Sunglasses...  ₹379
#
# [100 rows x 3 columns]

# %%
#Q5: Scrape 100 reviews data from flipkart.com for iphone11 phone
#Rating
#2. Review summary
#3. Full review
#4. You have to scrape this data for first 100 reviews

# %%
driver=webdriver.Chrome(r'C:\Users\maham\Downloads\chromedriver\chromedriver.exe') #copy the path of the chromedriver

# %%
url='https://www.flipkart.com/apple-iphone-11-black-64-gb/p/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&marketplace=FLIPKART&q=apple+iphone+11+black+64&store=tyy%2F4io&srno=s_1_1&otracker=AS_QueryStore_OrganicAutoSuggest_2_19_sc_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_2_19_sc_na_na&fm=organic&iid=6bb9d90b-2054-4380-b1d5-9eec5599573a.MOBFWQ6BXGJCEYNY.SEARCH&ppt=hp&ppn=homepage&ssid=ji0p26m7k00000001667647628410&qH=48e1abecb4fa35d9'
driver.get(url)

# %%
search=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[9]/div[7]/div/a/div').click()

# %%
rating=[]
start=0
end=10

for page in range(start,end):
    titles=driver.find_elements(By.XPATH,"//div[@class='_3LWZlK _1BLPMq']")
    for i in titles:
        rating.append(i.text)
    next_button=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div/div/div[2]/div[2]')
    next_button.click()
    time.sleep(3)

    
rating
# Out:
# ['4',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '4',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '4',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '4',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '4',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '4',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '4',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '4',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '4',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '4',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5']

# %%
len(rating)
# Out:
# 100

# %%
review=[]
start=0
end=10

for page in range(start,end):
    titles=driver.find_elements(By.XPATH,"//p[@class='_2-N8zT']")
    for i in titles:
        review.append(i.text)
    next_button=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div/div/div[2]/div[2]')
    next_button.click()
    time.sleep(3)

    
review
# Out:
# ['Pretty good',
#  'Worth every penny',
#  'Classy product',
#  'Good choice',
#  'Perfect product!',
#  'Highly recommended',
#  'Perfect product!',
#  'Perfect product!',
#  'Value-for-money',
#  'Highly recommended',
#  'Pretty good',
#  'Worth every penny',
#  'Classy product',
#  'Good choice',
#  'Perfect product!',
#  'Highly recommended',
#  'Perfect product!',
#  'Perfect product!',
#  'Value-for-money',
#  'Highly recommended',
#  'Pretty good',
#  'Worth every penny',
#  'Classy product',
#  'Good choice',
#  'Perfect product!',
#  'Highly recommended',
#  'Perfect product!',
#  'Perfect product!',
#  'Value-for-money',
#  'Highly recommended',
#  'Pretty good',
#  'Worth every penny',
#  'Classy product',
#  'Good choice',
#  'Perfect product!',
#  'Highly recommended',
#  'Perfect product!',
#  'Perfect product!',
#  'Value-for-money',
#  'Highly recommended',
#  'Pretty good',
#  'Worth every penny',
#  'Classy product',
#  'Good choice',
#  'Perfect product!',
# ...

# %%
len(review)
# Out:
# 100

# %%
full_review=[]
start=0
end=10

for page in range(start,end):
    titles=driver.find_elements(By.XPATH,"//div[@class='t-ZTKy']")
    for i in titles:
        full_review.append(i.text)
    next_button=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div/div/div[2]/div[2]')
    next_button.click()
    time.sleep(3)

    
full_review
# Out:
# ['I was using Iphone 6s and also Oneplus 6t. Both mobiles were perfectly alright in Photos, gaming, and smooth interface . My 6s mobile getting battery issue. thought upgrade to 11. Really like this mobile of its Internal storage (compare to 6s) , camera and its touch feeling. Its a worth buying mobile for me.',
#  'i11 is worthy to buy, too much happy with the product. Thank u flipkart I received the item on time..loved it..',
#  'Best and amazing product.....phone looks so premium.... battary is also good as expected .... Wide angle camera is so addictive ...if you are a IOS lover....then this phone will be the best choice for you all!!💯🔥',
#  'So far it’s been an AMAZING experience coming back to iOS after nearly a decade but it’s not as versatile as android though phone is sturdy dropped it accidentally a couple of times and nothing happened fortunately camera is awesome',
# ...

# %%
len(full_review)
# Out:
# 100

# %%
iphone=pd.DataFrame()
iphone['rating']=rating
iphone['review']=review
iphone['full_review']=full_review
iphone
# Out:
#    rating              review  \
# 0       4         Pretty good
# 1       5   Worth every penny
# 2       5      Classy product
# 3       4         Good choice
# 4       5    Perfect product!
# ..    ...                 ...
# 95      5  Highly recommended
# 96      5    Perfect product!
# 97      5    Perfect product!
# 98      4     Value-for-money
# 99      5  Highly recommended
#
#                                           full_review
# 0   I was using Iphone 6s and also Oneplus 6t. Bot...
# 1   i11 is worthy to buy, too much happy with the ...
# 2   Best and amazing product.....phone looks so pr...
# 3   So far it’s been an AMAZING experience coming ...
# 4   It’s a must buy who is looking for an upgrade ...
# ..                                                ...
# 95  iphone 11 is a very good phone to buy only if ...
# 96  Value for money❤️❤️\nIts awesome mobile phone ...
# 97  It is just awesome mobile for this price from ...
# ...

# %%
#Q6: Scrape data for first 100 sneakers you find when you visit flipkart.com and search for “sneakers” in the
#search field.
#You have to scrape 4 attributes of each sneaker:
#1. Brand
#2. Product Description
#3. Price

# %%
driver=webdriver.Chrome(r'C:\Users\maham\Downloads\chromedriver\chromedriver.exe') #copy the path of the chromedriver

# %%
url='https://www.flipkart.com/'
driver.get(url)

# %%
search_product=driver.find_element(By.CLASS_NAME,"_3704LK")
search_product.send_keys("Sneakers")

# %%
click_search=driver.find_element(By.CLASS_NAME,"L0Z3Pu").click()

# %%
product1=[]

start=0
end=2

for page in range(start,end):
    titles=driver.find_elements(By.XPATH,"//div[@class='_2WkVRV']")
    for i in titles:
        product1.append(i.text)
    next_button=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[2]')
    next_button.click()
    time.sleep(3) 
    
titles=driver.find_elements(By.XPATH,"//div[@class='_2WkVRV']")    
for j in titles[0:20]:
    product1.append(j.text)
next_button=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[4]')
next_button.click()
time.sleep(3)
    

product1
# Out:
# ['Rugbi',
#  'VENDOZ',
#  'RED TAPE',
#  'Labbin',
#  'BRUTON',
#  'Magnolia',
#  'RED TAPE',
#  'PUMA',
#  'T-ROCK',
#  'DUCATI',
#  'PUMA',
#  'CALCADOS',
#  'TR',
#  'Kraasa',
#  'TR',
#  'BRUTON',
#  'PUMA',
#  'asian',
#  'World Wear Footwear',
#  'Deals4you',
#  'ACTION',
#  'PUMA',
#  'DUCATI',
#  'PUMA',
#  'Robbie jones',
#  'ASTEROID',
#  'PUMA',
#  'STEPWAY',
#  'Magnolia',
#  'BRUTON',
#  'PUMA',
#  'PUMA',
#  'asics',
#  'DUCATI',
#  'SCATCHITE',
#  'BRUTON',
#  'YALA',
#  'FOOTSTAIR',
#  'BRUTON',
#  'aadi',
#  'VENDOZ',
#  'VENDOZ',
#  'RINDAS',
#  'kardam&sons',
#  'BRUTON',
#  'RapidBox',
#  'chelsi shoes',
#  'VENDOZ',
#  'BIRDE',
#  'ASTEROID',
#  'VENDOZ',
#  'asian',
#  'Robbie jones',
#  'Sparx',
#  'KWIK FIT',
#  'DUCATI',
#  'Kraasa',
#  'WARMFEET',
#  'Xtoon',
#  'aadi',
#  'KNIGHT WALKERS',
#  'VENDOZ',
#  'Shozie',
#  'LNT FASHION',
#  'Shozie',
#  'AMICO',
#  'VENDOZ',
#  'chelsi shoes',
#  'HOTSTYLE',
#  'BRUTON',
#  'VENDOZ',
#  'PUMA',
#  'DUCATI',
# ...

# %%
len(product1)
# Out:
# 100

# %%
pro_des=[]

start=0
end=2

for page in range(start,end):
    titles=driver.find_elements(By.XPATH,"//a[@class='IRpwTa']")
    for i in titles:
        pro_des.append(i.text)
    next_button=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[1]')
    next_button.click()
    time.sleep(3) 
    

titles=driver.find_elements(By.XPATH,"//a[@class='IRpwTa']")    
for j in titles[0:26]:
    pro_des.append(j.text)
next_button=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[4]')
next_button.click()
time.sleep(3) 
pro_des.append("sneakers")
pro_des.append("sneakers1")
pro_des.append("sneakers2")

pro_des
# Out:
# ['Sneakers For Men',
#  'Sneakers For Men',
#  'Sneakers For Women',
#  'SD-323 Sneakers For Men',
#  'Casual Sneakers White Outdoor Shoes For Boys And Men Sn...',
#  'Sneakers For Men',
#  'Pint Sneakers For Men',
#  'Jada Night Out Sneakers For Women',
#  'Sneakers For Men',
#  'Sneakers For Men',
#  'Kaia Platform Sneakers For Women',
#  'Venus Sneakers For Women',
#  'Sneakers For Men',
#  'Outdoor Trendy Lightweight Casual,Canvas Stylish Partyw...',
#  'Sneakers For Men',
#  'Sneakers For Men',
#  'Bella V Patent Sneakers For Women',
#  'Harrow Wns Sneakers For Women',
#  'Mesh,Cricket, Badminton,Volly Ball,Sports,Casual,Walkin...',
#  'Skye Clean Sneakers For Women',
#  'Sneakers For Men',
#  'Sneakers For Women',
#  'Men White Sneakers Sneakers For Men',
#  'Sneakers For Men',
#  'x KL Columbus Sneakers For Men',
#  'Adelina Sneakers For Women',
#  'Sneakers For Men',
#  'SM-671 Sneakers For Men',
#  "Comfort Wn's Slip on Sneakers For Women",
# ...

# %%
len(pro_des)
# Out:
# 100

# %%
price=[]

start=0
end=2

for page in range(start,end):
    titles=driver.find_elements(By.XPATH,"//div[@class='_30jeq3']")
    for i in titles:
        price.append(i.text)
    next_button=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[2]')
    next_button.click()
    time.sleep(3) 
    
titles=driver.find_elements(By.XPATH,"//div[@class='_30jeq3']")    
for j in titles[0:20]:
    price.append(j.text)
next_button=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[4]')
next_button.click()
time.sleep(3)
    

price
# Out:
# ['₹2,729',
#  '₹3,499',
#  '₹1,149',
#  '₹395',
#  '₹349',
#  '₹199',
#  '₹395',
#  '₹8,499',
#  '₹1,241',
#  '₹299',
#  '₹389',
#  '₹3,159',
#  '₹499',
#  '₹449',
#  '₹449',
#  '₹2,020',
#  '₹1,959',
#  '₹6,369',
#  '₹324',
#  '₹363',
#  '₹1,919',
#  '₹1,559',
#  '₹249',
#  '₹1,219',
#  '₹1,427',
#  '₹360',
#  '₹6,799',
#  '₹1,289',
#  '₹499',
#  '₹249',
#  '₹7,649',
#  '₹5,949',
#  '₹329',
#  '₹324',
#  '₹499',
#  '₹199',
#  '₹6,799',
#  '₹1,679',
#  '₹298',
#  '₹1,299',
#  '₹499',
#  '₹498',
#  '₹298',
#  '₹499',
#  '₹329',
#  '₹299',
#  '₹499',
#  '₹498',
#  '₹449',
#  '₹449',
#  '₹499',
#  '₹499',
#  '₹434',
#  '₹824',
#  '₹599',
#  '₹399',
#  '₹499',
#  '₹616',
#  '₹299',
#  '₹399',
#  '₹499',
#  '₹599',
#  '₹1,169',
#  '₹267',
#  '₹350',
#  '₹299',
#  '₹499',
#  '₹429',
#  '₹799',
#  '₹249',
#  '₹499',
#  '₹499',
#  '₹494',
#  '₹398',
#  '₹1,249',
#  '₹317',
#  '₹428',
#  '₹649',
#  '₹1,966',
#  '₹298',
#  '₹498',
#  '₹499',
#  '₹1,149',
#  '₹395',
#  '₹349',
#  '₹199',
# ...

# %%
len(price)
# Out:
# 100

# %%
discount=[]

start=0
end=2

for page in range(start,end):
    titles=driver.find_elements(By.XPATH,"//div[@class='_3Ay6Sb']")
    for i in titles:
        discount.append(i.text)
    next_button=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[2]')
    next_button.click()
    time.sleep(3) 
    
titles=driver.find_elements(By.XPATH,"//div[@class='_3Ay6Sb']")    
for j in titles[0:20]:
    discount.append(j.text)
next_button=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[4]')
next_button.click()
time.sleep(3)
    

discount
# Out:
# ['60% off',
#  '15% off',
#  '63% off',
#  '77% off',
#  '54% off',
#  '61% off',
#  '54% off',
#  '22% off',
#  '62% off',
#  '52% off',
#  '57% off',
#  '25% off',
#  '76% off',
#  '70% off',
#  '63% off',
#  '55% off',
#  '73% off',
#  '51% off',
#  '28% off',
#  '61% off',
#  '25% off',
#  '25% off',
#  '61% off',
#  '63% off',
#  '25% off',
#  '77% off',
#  '15% off',
#  '15% off',
#  '69% off',
#  '68% off',
#  '52% off',
#  '61% off',
#  '71% off',
#  '67% off',
#  '76% off',
#  '58% off',
#  '15% off',
#  '15% off',
#  '31% off',
#  '50% off',
#  '52% off',
#  '50% off',
#  '77% off',
#  '60% off',
#  '65% off',
#  '66% off',
#  '60% off',
#  '50% off',
#  '77% off',
#  '70% off',
#  '55% off',
#  '53% off',
#  '50% off',
#  '70% off',
#  '70% off',
#  '42% off',
#  '52% off',
#  '57% off',
#  '75% off',
#  '63% off',
#  '52% off',
#  '73% off',
#  '83% off',
#  '65% off',
#  '62% off',
#  '63% off',
#  '20% off',
#  '35% off',
#  '75% off',
#  '80% off',
#  '52% off',
# ...

# %%
len(discount)
# Out:
# 100

# %%
sneakers=pd.DataFrame()
sneakers['product']=product1
sneakers['product description']=pro_des
sneakers['price']=price
sneakers['discount']=discount
sneakers
# Out:
#                 product                                product description  \
# 0                 Rugbi                                   Sneakers For Men
# 1                VENDOZ                                   Sneakers For Men
# 2              RED TAPE                                 Sneakers For Women
# 3                Labbin                            SD-323 Sneakers For Men
# 4                BRUTON  Casual Sneakers White Outdoor Shoes For Boys A...
# ..                  ...                                                ...
# 95               BRUTON                          Sneakers Sneakers For Men
# 96             CALCADOS                Mirage Sport Remix Sneakers For Men
# 97                 PUMA                                           sneakers
# 98  World Wear Footwear                                          sneakers1
# 99            Deals4you                                          sneakers2
#
#      price discount
# 0   ₹2,729  60% off
# 1   ₹3,499  15% off
# ...

# %%
#Q7: Go to the link - https://www.myntra.com/shoes
#Set second Price filter and Color filter to “Black”, as shown in the below image.

# %%
driver=webdriver.Chrome(r'C:\Users\maham\Downloads\chromedriver\chromedriver.exe') #copy the path of the chromedriver

# %%
url='https://www.myntra.com/shoes'
driver.get(url)

# %%
search_loc=driver.find_element(By.XPATH,'/html/body/div[2]/div/main/div[3]/div[1]/section/div/div[5]/ul/li[2]/label').click()

# %%
search_loc=driver.find_element(By.XPATH,'/html/body/div[2]/div/main/div[3]/div[1]/section/div/div[6]/ul/li[1]').click()

# %%
brand=[]

start=0
end=2

for page in range(start,end):
    titles=driver.find_elements(By.XPATH,"//h3[@class='product-brand']")
    for i in titles:
        brand.append(i.text)
    next_button=driver.find_element(By.XPATH,'/html/body/div[2]/div/main/div[3]/div[2]/div/div[2]/section/div[2]/ul/li[3]')
    next_button.click()
    time.sleep(3) 
    

    

brand
# Out:
# ['ALDO',
#  'Geox',
#  'Skechers',
#  'ALDO',
#  'Clarks',
#  'New Balance',
#  'Puma',
#  'Geox',
#  'Reebok',
#  'Bugatti',
#  'Nike',
#  'Louis Philippe',
#  'Geox',
#  'ALDO',
#  'Heel & Buckle London',
#  'Bugatti',
#  'Puma',
#  'ROSSO BRUNELLO',
#  'fitflop',
#  'ALDO',
#  'Nike',
#  'Xtep',
#  'ROSSO BRUNELLO',
#  'Tommy Hilfiger',
#  'Saint G',
#  'Geox',
#  'Saint G',
#  'Saint G',
#  'Calvin Klein',
#  'Calvin Klein',
#  'Tommy Hilfiger',
#  'ALDO',
#  'Columbia',
#  'Geox',
#  'ALDO',
#  'Calvin Klein',
#  'ALDO',
#  'Tommy Hilfiger',
#  'Tommy Hilfiger',
#  'ALDO',
#  'Tommy Hilfiger',
#  'Saint G',
#  'DAVINCHI',
#  'H&M',
#  'ALDO',
#  'Saint G',
#  'ALDO',
#  'Columbia',
#  'Metro',
#  'ADIDAS',
#  'UNDER ARMOUR',
#  'Nike',
#  'UNDER ARMOUR',
#  'Nike',
#  'ADIDAS Originals',
#  'Nike',
#  'Tommy Hilfiger',
#  'UNDER ARMOUR',
#  'UNDER ARMOUR',
#  'Nike',
#  'ADIDAS',
#  'Ruosh',
#  'Puma',
#  'UNDER ARMOUR',
#  'ADIDAS Originals',
#  'ADIDAS',
#  'Nike',
#  'Nike',
# ...

# %%
len(brand)
# Out:
# 100

# %%
Product_des=[]

start=0
end=2

for page in range(start,end):
    titles=driver.find_elements(By.XPATH,"//h4[@class='product-product']")
    for i in titles:
        Product_des.append(i.text)
    next_button=driver.find_element(By.XPATH,'/html/body/div[2]/div/main/div[3]/div[2]/div/div[2]/section/div[2]/ul/li[3]')
    next_button.click()
    time.sleep(3) 
    

    

Product_des
# Out:
# ['Men Adistar Running Shoes',
#  'Unisex Curry Basketball Shoes',
#  'Men KD 15 Basketball Shoes',
#  'Men Adistar CS Running Shoes',
#  'Men Textured Leather Loafers',
#  'Women Go Walk EU Walking Shoes',
#  'Block Heeled Boots',
#  'Men Leather Sneakers',
#  'Women Forum Low Sneakers',
#  'Women High-Top Heeled Boots',
#  'Women AIR ZOOM Running Shoes',
#  'Men Skate Shoes',
#  'Men Mid Top Lace Up Sneakers',
#  'Men 4DFWD_Pulse Running Shoes',
#  'Women Leather Boots',
#  'Men Solid Sneakers',
#  'Men Running Sports Shoes',
#  'Men JORDAN LOW Basketball Shoe',
#  'Men Basketball Shoes',
#  'Men Runner Fl Running Shoes',
#  'Women Run XX Nitro Running',
#  'Women UltraRide Running Shoes',
#  'Men GO FLEX 2-COMPLETION Shoes',
#  'Men Sky Vault Walking Shoes',
#  'Women Velocity Nitro 2 Running',
#  'Men Waffle Leather Sneakers',
#  'Men MAX ELITE Running Shoes',
#  'Men Woven FomSolution Sneakers',
#  'Leather Block Heeled Boots',
#  'Men Retropy F90 Sneakers',
# ...

# %%
len(Product_des)
# Out:
# 100

# %%
price=[]

start=0
end=2

for page in range(start,end):
    titles=driver.find_elements(By.XPATH,"//div[@class='product-price']")
    for i in titles:
        price.append(i.text)
    next_button=driver.find_element(By.XPATH,'/html/body/div[2]/div/main/div[3]/div[2]/div/div[2]/section/div[2]/ul/li[3]')
    next_button.click()
    time.sleep(3) 
    

    

price
# Out:
# ['Rs. 13999',
#  'Rs. 8990',
#  'Rs. 13990',
#  'Rs. 12999',
#  'Rs. 13410Rs. 14900(10% OFF)',
#  'Rs. 8295',
#  'Rs. 12510Rs. 13900(10% OFF)',
#  'Rs. 7199Rs. 8999(20% OFF)',
#  'Rs. 11990',
#  'Rs. 12999',
#  'Rs. 11999Rs. 15999(25% OFF)',
#  'Rs. 8396Rs. 10495(20% OFF)',
#  'Rs. 7499',
#  'Rs. 7560Rs. 8400(10% OFF)',
#  'Rs. 13999',
#  'Rs. 8490',
#  'Rs. 9999',
#  'Rs. 10710Rs. 11900(10% OFF)',
#  'Rs. 8750Rs. 10295(15% OFF)',
#  'Rs. 7999Rs. 9999(20% OFF)',
#  'Rs. 8999',
#  'Rs. 7649Rs. 8999(15% OFF)',
#  'Rs. 9599Rs. 15999(40% OFF)',
#  'Rs. 13166Rs. 15490(15% OFF)',
#  'Rs. 10999',
#  'Rs. 9810Rs. 10900(10% OFF)',
#  'Rs. 8999Rs. 11999(25% OFF)',
#  'Rs. 7499',
#  'Rs. 8999',
#  'Rs. 9999',
#  'Rs. 7649Rs. 8999(15% OFF)',
#  'Rs. 11470Rs. 13495(15% OFF)',
#  'Rs. 10499Rs. 14999(30% OFF)',
#  'Rs. 7699Rs. 10999(30% OFF)',
#  'Rs. 8750Rs. 10295(15% OFF)',
#  'Rs. 7199Rs. 8999(20% OFF)',
#  'Rs. 7199Rs. 7999(10% OFF)',
#  'Rs. 9999',
#  'Rs. 8010Rs. 8900(10% OFF)',
# ...

# %%
len(price)
# Out:
# 100

# %%
Myntra=pd.DataFrame()
Myntra['brand']=brand
Myntra['Product description']=Product_des
Myntra['Price']=price
Myntra
# Out:
#                brand             Product description  \
# 0               ALDO       Men Adistar Running Shoes
# 1               Geox   Unisex Curry Basketball Shoes
# 2           Skechers      Men KD 15 Basketball Shoes
# 3               ALDO    Men Adistar CS Running Shoes
# 4             Clarks    Men Textured Leather Loafers
# ..               ...                             ...
# 95            ADIDAS  Men JORDAN LOW Basketball Shoe
# 96  ADIDAS Originals       Leather Kitten Heel Boots
# 97              Puma               Men Walking Shoes
# 98           Saint G    Men Textured Leather Brogues
# 99            ADIDAS             Women Regular Boots
#
#                           Price
# 0                     Rs. 13999
# 1                      Rs. 8990
# 2                     Rs. 13990
# 3                     Rs. 12999
# 4   Rs. 13410Rs. 14900(10% OFF)
# ..                          ...
# 95                    Rs. 12795
# 96   Rs. 9810Rs. 10900(10% OFF)
# ...

# %%
#Q8: Go to webpage https://www.amazon.in/
#Enter “Laptop” in the search field and then click the search icon.

# %%
driver=webdriver.Chrome(r'C:\Users\maham\Downloads\chromedriver\chromedriver.exe') #copy the path of the chromedriver

# %%
url='https://www.amazon.in/'
driver.get(url)

# %%
search_product=driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input')
search_product.send_keys("laptop")

# %%
search_btn=driver.find_element(By.CLASS_NAME,"nav-right")
search_btn.click()

# %%
search_i7=driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[5]/ul[5]/li[10]/span/a/span').click()

# %%
lap_title=[]
title_tags=driver.find_elements(By.XPATH,"//h2[@class='a-size-mini a-spacing-none a-color-base s-line-clamp-2']")
for i in title_tags[0:10]:
    lap_title.append(i.text)
    
lap_title
# Out:
# ['Lenovo ThinkBook 15 Intel 11th Gen Core i7 15.6"(39.62 cm) FHD Thin and Light Laptop (16GB/512GB SSD/Windows 11 Home/MS Office H&S 2021/Iris® Xe Graphics/Backlit/Mineral Grey/1.7 Kg) 20VE00W4IH',
#  'Dell Inspiron 5320 Laptop, i7-1260P, 16GB LPDDR5, 512GB SSD, Integrated, 13.3" (33.78Cms) QHD+ WVA AG 300 nits, Win 11+ MSO\'21, Platinum Silver (D560754WIN9S, 1.25Kgs)',
#  'HP Pavilion x360 11th Gen Intel Core i7 14 inch(35.6 cm) FHD,IPS, Multitouch 2-in-1 Laptop(16GB RAM/512GB SSD/Backlit KB/Intel Iris Xe Graphics/Pen/Alexa Built-in/MSO/1.52Kg) 14-dy1050TU, Spruce Blue',
#  'Lenovo IdeaPad Slim 5 12th Gen Intel Core i7 15.6"(39.62cm) FHD IPS Laptop (16GB/512GB SSD/Win 11/Office 2021/Backlit KB/Fingerprint/FHD Camera/Alexa/3 Month Game Pass/Storm Grey/1.85Kg), 82SF004XIN',
#  'HP Pavilion Plus, 12th Gen Intel Core i7 16GB RAM/1TB SSD 14 inch(35.6 cm),OLED,400 nits,UWVA, Eye Safe Laptop/Intel Iris Xe Graphics/Backlit KB/B&O/FPR/Win 11/Alexa Built-in/MSO 2021, 14-eh0024TU',
# ...

# %%
len(lap_title)
# Out:
# 10

# %%
price=[]
title_tags=driver.find_elements(By.XPATH,"//span[@class='a-price-whole']")
for i in title_tags[0:10]:
    price.append(i.text)
    
price
# Out:
# ['77,990',
#  '84,918',
#  '80,490',
#  '83,990',
#  '93,999',
#  '25,990',
#  '25,895',
#  '45,990',
#  '85,330',
#  '86,490']

# %%
len(price)
# Out:
# 10

# %%
rate=[]
title_tags=driver.find_elements(By.XPATH,"//span[@class='a-icon-alt']")
for i in title_tags[0:10]:
    rate.append(i.text)
    
rate
# Out:
# ['', '', '', '', '', '', '', '', '', '']

# %%
laptop=pd.DataFrame()
laptop['Brand']=lap_title
laptop['Price']=price
laptop['rate']=rate
laptop
# Out:
#                                                Brand   Price rate
# 0  Lenovo ThinkBook 15 Intel 11th Gen Core i7 15....  77,990
# 1  Dell Inspiron 5320 Laptop, i7-1260P, 16GB LPDD...  84,918
# 2  HP Pavilion x360 11th Gen Intel Core i7 14 inc...  80,490
# 3  Lenovo IdeaPad Slim 5 12th Gen Intel Core i7 1...  83,990
# 4  HP Pavilion Plus, 12th Gen Intel Core i7 16GB ...  93,999
# 5  (Renewed) HP Workstation Zbook Intel Core i7-4...  25,990
# 6  (Renewed) HP ProBook 430 G3 6th Gen Intel Core...  25,895
# 7  (Renewed) HP Workstation Zbook Intel Core i7-4...  45,990
# 8  (Renewed) Fujitsu UH-X 12th Gen Intel Evo Core...  85,330
# 9  Lenovo ThinkBook 15 Intel 12th Gen Core i7 15....  86,490

# %%
driver=webdriver.Chrome(r'C:\Users\maham\Downloads\chromedriver\chromedriver.exe') #copy the path of the chromedriver

# %%
url='https://www.azquotes.com/'
driver.get(url)

# %%
search_loc=driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div[1]/div/div[3]/ul/li[5]/a').click()

# %%
quote=[]

title_tags=driver.find_elements(By.XPATH,"//a[@class='title']")
for i in title_tags[0:10]:
    quote.append(i.text)

quote
# Out:
# ['The essence of strategy is choosing what not to do.',
#  'One cannot and must not try to erase the past merely because it does not fit the present.',
#  'Patriotism means to stand by the country. It does not mean to stand by the president.',
#  'Death is something inevitable. When a man has done what he considers to be his duty to his people and his country, he can rest in peace. I believe I have made that effort and that is, therefore, why I will sleep for the eternity.',
#  'You have to love a nation that celebrates its independence every July 4, not with a parade of guns, tanks, and soldiers who file by the White House in a show of strength and muscle, but with family picnics where kids throw Frisbees, the potato salad gets iffy, and the flies die from happiness. You may think you have overeaten, but it is patriotism.',
# ...

# %%
len(quote)
# Out:
# 10

# %%
author=[]



title_tags=driver.find_elements(By.XPATH,"//div[@class='author']")
for i in title_tags[0:10]:
    author.append(i.text)

author
# Out:
# ['Michael Porter',
#  'Golda Meir',
#  'Theodore Roosevelt',
#  'Nelson Mandela',
#  'Erma Bombeck',
#  'John Wooden',
#  'Albert Einstein',
#  'Frank Zappa',
#  'William Faulkner',
#  'Will Rogers']

# %%
len(author)
# Out:
# 10

# %%
tags=[]

title_tags=driver.find_elements(By.XPATH,"//div[@class='tags']")
for i in title_tags[0:10]:
    tags.append(i.text)

tags
# Out:
# ['Essence, Deep Thought, Transcendentalism',
#  'Inspiration, Past, Trying',
#  'Country, Peace, War',
#  'Inspirational, Motivational, Death',
#  '4th Of July, Food, Patriotic',
#  'Inspirational, Success, Basketball',
#  'Strong, Revenge, Intelligent',
#  'Inspirational, Teacher, Religious',
#  'Truth, Honesty, Lying',
#  'Funny, Reading, Learning']

# %%
Famous_Quote=pd.DataFrame()
Famous_Quote['Quotes']=quote
Famous_Quote['Author']=author
Famous_Quote['tags']=tags
Famous_Quote
# Out:
#                                               Quotes              Author  \
# 0  The essence of strategy is choosing what not t...      Michael Porter
# 1  One cannot and must not try to erase the past ...          Golda Meir
# 2  Patriotism means to stand by the country. It d...  Theodore Roosevelt
# 3  Death is something inevitable. When a man has ...      Nelson Mandela
# 4  You have to love a nation that celebrates its ...        Erma Bombeck
# 5  Be more concerned with your character than you...         John Wooden
# 6  Weak people revenge. Strong people forgive. In...     Albert Einstein
# 7  A mind is like a parachute. It doesn't work if...         Frank Zappa
# 8  Never be afraid to raise your voice for honest...    William Faulkner
# 9  There are three kinds of men. The one that lea...         Will Rogers
#
#                                        tags
# 0  Essence, Deep Thought, Transcendentalism
# 1                 Inspiration, Past, Trying
# ...
